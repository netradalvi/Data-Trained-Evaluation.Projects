# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('loan_prediction.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# # Problem Statement:-
#
# This dataset includes details of applicants who have applied for loan. The dataset includes details like credit history, loan amount, their income, dependents etc.
#
# Independent Variables:
#
# - Loan_ID
#
# - Gender
#
# - Married
#
# - Dependents
#
# - Education
#
# - Self_Employed
#
# - ApplicantIncome
#
# - CoapplicantIncome
#
# - Loan_Amount
#
# - Loan_Amount_Term
#
# - Credit History
#
# - Property_Area
#
# Dependent Variable (Target Variable):
#
# - Loan_Status
#
# You have to build a model that can predict whether the loan of the applicant will be approved or not on the basis of the details provided in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df.groupby('Gender')['Married'].value_counts()
# Out:
# Gender  Married
# Female  No          80
#         Yes         31
# Male    Yes        357
#         No         130
# Name: Married, dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df[df['Credit_History'].isna()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 16   LP001034    Male      No          1  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 42   LP001123    Male     Yes          0      Graduate            No
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 83   LP001273    Male     Yes          0      Graduate            No
# 86   LP001280    Male     Yes          2  Not Graduate            No
# 95   LP001326    Male      No          0      Graduate           NaN
# 117  LP001405    Male     Yes          1      Graduate            No
# 125  LP001443  Female      No          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 156  LP001541    Male     Yes          1      Graduate            No
# 181  LP001634    Male      No          0      Graduate            No
# 187  LP001643    Male     Yes          0      Graduate            No
# 198  LP001671  Female     Yes          0      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 236  LP001786    Male     Yes          0      Graduate           NaN
# 237  LP001788  Female      No          0      Graduate           Yes
# 259  LP001864    Male     Yes         3+  Not Graduate            No
# 260  LP001865    Male     Yes          1      Graduate            No
# 279  LP001908  Female     Yes          0  Not Graduate            No
# 309  LP001998    Male     Yes          2  Not Graduate            No
# 313  LP002008    Male     Yes          2      Graduate           Yes
# 317  LP002036    Male     Yes          0      Graduate            No
# 318  LP002043  Female      No          1      Graduate            No
# 323  LP002055  Female      No          0      Graduate            No
# 348  LP002137    Male     Yes          0      Graduate            No
# 363  LP002178    Male     Yes          0      Graduate            No
# 377  LP002223    Male     Yes          0      Graduate            No
# 392  LP002263    Male     Yes          0      Graduate            No
# 395  LP002272    Male     Yes          2      Graduate            No
# 411  LP002319    Male     Yes          0      Graduate           NaN
# 444  LP002424    Male     Yes          0      Graduate            No
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 451  LP002447    Male     Yes          2  Not Graduate            No
# 460  LP002478     NaN     Yes          0      Graduate           Yes
# 473  LP002522  Female      No          0      Graduate           Yes
# 490  LP002560    Male      No          0  Not Graduate            No
# 491  LP002562    Male     Yes          1  Not Graduate            No
# 497  LP002588    Male     Yes          0      Graduate            No
# 503  LP002618    Male     Yes          1  Not Graduate            No
# 506  LP002624    Male     Yes          0      Graduate            No
# 530  LP002717    Male     Yes          0      Graduate            No
# 533  LP002729    Male      No          1      Graduate            No
# 544  LP002757  Female     Yes          0  Not Graduate            No
# 556  LP002794  Female      No          0      Graduate            No
# 565  LP002833    Male     Yes          0  Not Graduate            No
# 583  LP002898    Male     Yes          1      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 16              3596                0.0       100.0             240.0
# 24              3717             2925.0       151.0             360.0
# 30              4166             3369.0       201.0             360.0
# 42              2400                0.0        75.0             360.0
# 79              3333             2166.0       130.0             360.0
# 83              6000             2250.0       265.0             360.0
# 86              3333             2000.0        99.0             360.0
# 95              6782                0.0         NaN             360.0
# 117             2214             1398.0        85.0             360.0
# 125             3692                0.0        93.0             360.0
# 129             6080             2569.0       182.0             360.0
# 130            20166                0.0       650.0             480.0
# 156             6000                0.0       160.0             360.0
# 181             1916             5063.0        67.0             360.0
# 187             2383             2138.0        58.0             360.0
# 198             3416             2816.0       113.0             360.0
# 219             4283             2383.0       127.0             360.0
# 236             5746                0.0       255.0             360.0
# 237             3463                0.0       122.0             360.0
# 259             4931                0.0       128.0             360.0
# 260             6083             4250.0       330.0             360.0
# 279             4100                0.0       124.0             360.0
# 309             7667                0.0       185.0             360.0
# 313             5746                0.0       144.0              84.0
# 317             2058             2134.0        88.0             360.0
# 318             3541                0.0       112.0             360.0
# 323             3166             2985.0       132.0             360.0
# 348             6333             4583.0       259.0             360.0
# 363             3013             3033.0        95.0             300.0
# 377             4310                0.0       130.0             360.0
# 392             2583             2115.0       120.0             360.0
# 395             3276              484.0       135.0             360.0
# 411             6256                0.0       160.0             360.0
# 444             7333             8333.0       175.0             300.0
# 449             2769             1542.0       190.0             360.0
# 451             1958             1456.0        60.0             300.0
# 460             2083             4083.0       160.0             360.0
# 473             2500                0.0        93.0             360.0
# 490             2699             2785.0        96.0             360.0
# 491             5333             1131.0       186.0             360.0
# 497             4625             2857.0       111.0              12.0
# 503             4050             5302.0       138.0             360.0
# 506            20833             6667.0       480.0             360.0
# 530             1025             5500.0       216.0             360.0
# 533            11250                0.0       196.0             360.0
# 544             3017              663.0       102.0             360.0
# 556             2667             1625.0        84.0             360.0
# 565             4467                0.0       120.0             360.0
# 583             1880                0.0        61.0             360.0
# 600              416            41667.0       350.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 16              NaN         Urban           Y
# 24              NaN     Semiurban           N
# 30              NaN         Urban           N
# 42              NaN         Urban           Y
# 79              NaN     Semiurban           Y
# 83              NaN     Semiurban           N
# 86              NaN     Semiurban           Y
# 95              NaN         Urban           N
# 117             NaN         Urban           Y
# 125             NaN         Rural           Y
# 129             NaN         Rural           N
# 130             NaN         Urban           Y
# 156             NaN         Rural           Y
# 181             NaN         Rural           N
# 187             NaN         Rural           Y
# 198             NaN     Semiurban           Y
# 219             NaN     Semiurban           Y
# 236             NaN         Urban           N
# 237             NaN         Urban           Y
# 259             NaN     Semiurban           N
# 260             NaN         Urban           Y
# 279             NaN         Rural           Y
# 309             NaN         Rural           Y
# 313             NaN         Rural           Y
# 317             NaN         Urban           Y
# 318             NaN     Semiurban           Y
# 323             NaN         Rural           Y
# 348             NaN     Semiurban           Y
# 363             NaN         Urban           Y
# 377             NaN     Semiurban           Y
# 392             NaN         Urban           Y
# 395             NaN     Semiurban           Y
# 411             NaN         Urban           Y
# 444             NaN         Rural           Y
# 449             NaN     Semiurban           N
# 451             NaN         Urban           Y
# 460             NaN     Semiurban           Y
# 473             NaN         Urban           Y
# 490             NaN     Semiurban           Y
# 491             NaN         Urban           Y
# 497             NaN         Urban           Y
# 503             NaN         Rural           N
# 506             NaN         Urban           Y
# 530             NaN         Rural           Y
# 533             NaN     Semiurban           N
# 544             NaN     Semiurban           Y
# 556             NaN         Urban           Y
# 565             NaN         Rural           Y
# 583             NaN         Rural           N
# 600             NaN         Urban           N

# %%
mode_of_credit=df.pivot_table(values='Credit_History',columns='Loan_Status',aggfunc=(lambda x:x.mode()))

# %%
mode_of_credit
# Out:
# Loan_Status       N    Y
# Credit_History  1.0  1.0

# %% [markdown]
# ## Observation:- Clearly the mode for Y and N is 1 so we can impute the missing value with 1.

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %% [markdown]
# # Univariate Analysis

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
sns.countplot('Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Married',data=df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Dependents',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Education',data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Self_Employed',data=df)
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Credit_History',data=df)
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Property_Area',data=df)
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Loan_Status',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot('Loan_Amount_Term',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='count'>

# %% [markdown]
# # Observation:-
#
# 1. The loan term of 360 has highest value.
#
# 2. SemiUrban property has highest value.
#
# 3. Male applicants has highest value.
#
# 4. 0 dependents has highest value.
#
# 5. Credit_history with value 1 has highest value.

# %%
df['Dependents']=df['Dependents'].replace('3+',3)

# %%
df['Loan_Status']=df['Loan_Status'].replace({'Y':1,'N':0})

# %% [markdown]
# # Bivariate analysis

# %%
plt.style.use('ggplot')
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='Gender'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='Married',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='Married'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Dependents',y='Loan_Status',data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='Loan_Status'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Self_Employed',y='Loan_Status',data=df)
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='Loan_Status'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='ApplicantIncome',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='CoapplicantIncome',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='CoapplicantIncome'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='LoanAmount',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='Loan_Amount_Term',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='Loan_Amount_Term'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='Credit_History',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='Credit_History'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='Loan_Status',y='Property_Area',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='Property_Area'>

# %% [markdown]
# # Observation:-
#
# 1. Male loan_status of getting approved is more.
#
# 2. Married people Loan Status getting approved is more as compared to unmarried.
#
# 3. No of dependent having 2 has more application approved.
#
# 4. Those who has less loan_amount and with 1 credit score gets loan approved frequently.
#
# 5. Semiurban property has high rate of loan approved

# %%
## Encoding categorial variable.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
categorial_variable=['Gender','Married','Education','Self_Employed','Property_Area']

# %%
df[categorial_variable]=df[categorial_variable].apply(le.fit_transform)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 57.7+ KB

# %%
df['Dependents']=df['Dependents'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %%
df['Total_Income']=df['ApplicantIncome']+df['CoapplicantIncome']
df.drop(columns=['CoapplicantIncome','ApplicantIncome'],axis=1,inplace=True)

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          0              0  146.412162
# 1         1        1           1          0              0  128.000000
# 2         1        1           0          0              1   66.000000
# 3         1        1           0          1              0  120.000000
# 4         1        0           0          0              0  141.000000
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          0              0   71.000000
# 610       1        1           3          0              0   40.000000
# 611       1        1           1          0              0  253.000000
# 612       1        1           2          0              0  187.000000
# 613       0        0           0          0              1  133.000000
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  \
# 0               360.0             1.0              2            1
# 1               360.0             1.0              0            0
# 2               360.0             1.0              2            1
# 3               360.0             1.0              2            1
# 4               360.0             1.0              2            1
# ..                ...             ...            ...          ...
# 609             360.0             1.0              0            1
# 610             180.0             1.0              0            1
# 611             360.0             1.0              2            1
# 612             360.0             1.0              2            1
# 613             360.0             0.0              1            0
#
#      Total_Income
# 0          5849.0
# 1          6091.0
# 2          3000.0
# 3          4941.0
# 4          6000.0
# ..            ...
# 609        2900.0
# 610        4106.0
# 611        8312.0
# 612        7583.0
# 613        4583.0
#
# [614 rows x 11 columns]

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df)

# %%
plt.figure(figsize=(20,20),facecolor='pink')

plotnumber=1

for column in df:
    if plotnumber <= 12:
        ax=plt.subplot(4,3,plotnumber)
        sns.distplot(df[column],color='k')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %% [markdown]
# # Observation:- skewness is there in some of the features, we have to treat them moving forward

# %%
plt.figure(figsize=(20,20),facecolor='orange')

plotnumber=1

for column in df:
    if plotnumber <= 15:
        ax=plt.subplot(5,3,plotnumber)
        sns.boxplot(df[column],color='k')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
## Removing outlier through Zscore

from scipy.stats import zscore
df.shape
# Out:
# (614, 11)

# %%
df=df[np.abs(zscore(df)<3).all(axis=1)]

# %%
df.shape
# Out:
# (593, 11)

# %%
data_loss=614-593
print(data_loss)
# Out:
# 21

# %%
print((21/614)*100)
# Out:
# 3.420195439739414

# %% [markdown]
# # Around 3.4 Percent data lost so we can proceed

# %%
plt.figure(figsize=(20,20),facecolor='orange')

plotnumber=1

for column in df:
    if plotnumber <= 15:
        ax=plt.subplot(5,3,plotnumber)
        sns.boxplot(df[column],color='k')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
# Checking skewness

df.skew()
# Out:
# Gender             -1.636802
# Married            -0.634856
# Dependents          1.029981
# Education           1.313788
# Self_Employed       2.207979
# LoanAmount          1.152306
# Loan_Amount_Term   -2.444945
# Credit_History     -2.021295
# Property_Area      -0.062701
# Loan_Status        -0.822267
# Total_Income        2.054852
# dtype: float64

# %%
# Separating target variable and features
X=df.drop('Loan_Status',axis=1)
y=df.Loan_Status

# %%
# Treating Skewness 
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')

# %%
x=pd.DataFrame(pt.fit_transform(X),columns=X.columns)
x
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0    0.474559 -1.365553   -0.818584  -0.540314      -0.386296    0.305121
# 1    0.474559  0.732304    0.878442  -0.540314      -0.386296   -0.017782
# 2    0.474559  0.732304   -0.818584  -0.540314       2.588687   -1.388753
# 3    0.474559  0.732304   -0.818584   1.850776      -0.386296   -0.167086
# 4    0.474559 -1.365553   -0.818584  -0.540314      -0.386296    0.212957
# ..        ...       ...         ...        ...            ...         ...
# 588 -2.107218 -1.365553   -0.818584  -0.540314      -0.386296   -1.254064
# 589  0.474559  0.732304    1.528790  -0.540314      -0.386296   -2.216911
# 590  0.474559  0.732304    0.878442  -0.540314      -0.386296    1.802695
# 591  0.474559  0.732304    1.331209  -0.540314      -0.386296    0.936941
# 592 -2.107218 -1.365553   -0.818584  -0.540314       2.588687    0.072612
#
#      Loan_Amount_Term  Credit_History  Property_Area  Total_Income
# 0            0.184909        0.411856       1.193325           0.0
# 1            0.184909        0.411856      -1.346142           0.0
# 2            0.184909        0.411856       1.193325           0.0
# 3            0.184909        0.411856       1.193325           0.0
# 4            0.184909        0.411856       1.193325           0.0
# ..                ...             ...            ...           ...
# 588          0.184909        0.411856      -1.346142           0.0
# 589         -2.328344        0.411856      -1.346142           0.0
# 590          0.184909        0.411856       1.193325           0.0
# 591          0.184909        0.411856       1.193325           0.0
# 592          0.184909       -2.428034       0.006832           0.0
#
# [593 rows x 10 columns]

# %%
x.skew()
# Out:
# Gender             -1.636802
# Married            -0.634856
# Dependents          0.458381
# Education           1.313788
# Self_Employed       2.207979
# LoanAmount          0.060144
# Loan_Amount_Term    0.404540
# Credit_History     -2.021295
# Property_Area      -0.157358
# Total_Income        0.000000
# dtype: float64

# %%
plt.figure(figsize=(20,20),facecolor='pink')

plotnumber=1

for column in x:
    if plotnumber <= 10:
        ax=plt.subplot(2,5,plotnumber)
        sns.distplot(x[column],color='k')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
x.shape
# Out:
# (818, 10)

# %%
y.shape
# Out:
# (818,)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.44704778, -1.34824351, -0.83233823, ...,  0.52358349,
#          1.23383978,  0.        ],
#        [ 0.44704778,  0.75031826,  0.87627974, ...,  0.52358349,
#         -1.3128002 ,  0.        ],
#        [ 0.44704778,  0.75031826, -0.83233823, ...,  0.52358349,
#          1.23383978,  0.        ],
#        ...,
#        [ 0.44704778,  0.75031826,  1.50226584, ...,  0.52358349,
#          0.04399525,  0.        ],
#        [ 0.44704778,  0.75031826,  1.33581094, ..., -1.92630085,
#         -1.28775853,  0.        ],
#        [ 0.44704778,  0.75031826, -0.14008389, ..., -1.92630085,
#         -1.3128002 ,  0.        ]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif          features
# 0  1.203161            Gender
# 1  1.395997           Married
# 2  1.231908        Dependents
# 3  1.051744         Education
# 4  1.027186     Self_Employed
# 5  1.106881        LoanAmount
# 6  1.053539  Loan_Amount_Term
# 7  1.009617    Credit_History
# 8  1.018848     Property_Area
# 9       NaN      Total_Income

# %%
## Since after removing skewness Total income becomes zero so dropping it.

x.drop('Total_Income',axis=1,inplace=True)

# %%
x
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0    0.474559 -1.365553   -0.818584  -0.540314      -0.386296    0.305121
# 1    0.474559  0.732304    0.878442  -0.540314      -0.386296   -0.017782
# 2    0.474559  0.732304   -0.818584  -0.540314       2.588687   -1.388753
# 3    0.474559  0.732304   -0.818584   1.850776      -0.386296   -0.167086
# 4    0.474559 -1.365553   -0.818584  -0.540314      -0.386296    0.212957
# ..        ...       ...         ...        ...            ...         ...
# 813  0.474559 -1.365553   -0.818584  -0.540314       0.977888    0.088589
# 814  0.474559  0.531220    0.878442  -0.540314       2.588687    0.361704
# 815  0.474559  0.732304    1.500182   1.850776      -0.386296    0.120457
# 816  0.474559  0.732304    1.334856   1.850776      -0.386296   -0.084237
# 817  0.474559  0.732304   -0.131026   1.850776       1.383359    0.238024
#
#      Loan_Amount_Term  Credit_History  Property_Area
# 0            0.184909        0.411856       1.193325
# 1            0.184909        0.411856      -1.346142
# 2            0.184909        0.411856       1.193325
# 3            0.184909        0.411856       1.193325
# 4            0.184909        0.411856       1.193325
# ..                ...             ...            ...
# 813         -0.967548        0.411856       1.193325
# 814          0.184909        0.411856      -1.346142
# 815          0.761485        0.411856       0.006832
# 816          0.177303       -2.428034      -1.321170
# 817         -2.328344       -2.428034      -1.346142
#
# [818 rows x 9 columns]

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x.corr(),annot=True,annot_kws={'size':10})
# Out:
# <AxesSubplot:>

# %%
## Transforming features into components through PCA

pca=PCA()
pca.fit_transform(x_scaled)
# Out:
# array([[ 1.10635368, -0.76511842,  0.37124747, ..., -0.40585674,
#         -0.81737713, -0.        ],
#        [-1.04166444, -0.49154094, -0.76994178, ...,  0.76608531,
#         -0.151955  , -0.        ],
#        [ 0.06314527, -0.07052655,  2.31250477, ...,  2.03963326,
#          1.06959884,  0.        ],
#        ...,
#        [-1.41431593,  0.95961834, -0.59335824, ..., -0.7226203 ,
#         -0.24018744, -0.        ],
#        [-1.46279015,  1.9672031 , -1.6337873 , ..., -0.25985396,
#         -0.21111658,  0.        ],
#        [-1.66489889,  2.23892071,  0.38930798, ..., -0.11362987,
#          0.51978778,  0.        ]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))

plt.ylabel('Varience Covered')
plt.title('PCA')
plt.show()

# %% [markdown]
# # Observation:- Since 8 components will give maximum variance in the data

# %%
pca=PCA(n_components=8)
new_pcomp=pca.fit_transform(x_scaled)
p_c=pd.DataFrame(new_pcomp,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8'])

# %%
p_c
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    1.106354 -0.765118  0.371247 -0.858156 -0.322111  0.273320 -1.163062
# 1   -1.041664 -0.491541 -0.769942  0.387443 -0.689039 -0.283557  0.865446
# 2    0.063145 -0.070527  2.312505 -0.335933  0.641744  1.207244 -0.736179
# 3   -0.218388  1.198413 -0.052509 -0.732576 -0.610376  1.475296 -0.967466
# 4    1.135313 -0.711490  0.380914 -0.878419 -0.338062  0.276382 -1.144905
# ..        ...       ...       ...       ...       ...       ...       ...
# 813  0.724686 -0.449952  1.792513 -0.110619 -0.046407  0.025307 -1.526167
# 814 -1.407692 -1.086007  1.188361  1.811737  0.784567  0.646260  0.602950
# 815 -1.414316  0.959618 -0.593358 -0.179287 -0.320539  1.549609  0.982143
# 816 -1.462790  1.967203 -1.633787  0.751475  1.250554 -0.020567  0.780331
# 817 -1.664899  2.238921  0.389308  2.254589  1.271380 -0.947297 -1.095772
#
#           PC8
# 0   -0.405857
# 1    0.766085
# 2    2.039633
# 3   -0.770143
# 4   -0.341612
# ..        ...
# 813  0.036531
# 814  1.409404
# 815 -0.722620
# 816 -0.259854
# 817 -0.113630
#
# [818 rows x 8 columns]

# %%
plt.figure(figsize=(15,7))
p_c.corrwith(y).plot(kind='bar',grid=True,title='Features vs Target')
# Out:
# <AxesSubplot:title={'center':'Features vs Target'}>

# %%
## Model Building 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix,classification_report,plot_roc_curve

# %%
x_train,x_test,y_train,y_test=train_test_split(p_c,y,test_size=0.25,random_state=41)

# %%
def model(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        ypred=clf.predict(x_train)
        print('  Training Result  ')
        print('Accuracy_Score: ',accuracy_score(y_train,ypred)*100)
        
    elif train==False:
        y_pred=clf.predict(x_test)
        print('   Test Result    ')
        print('Accuracy_Score: ',accuracy_score(y_test,y_pred)*100)
        print(confusion_matrix(y_test,y_pred))
        print(classification_report(y_test,y_pred))
        plt.figure(figsize=(15,7))
        sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,annot_kws={'size':10},fmt='0.2f')

# %%
# Logistic Regression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model(lr,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  70.30995106035888

# %%
model(lr,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  68.29268292682927
# [[51 58]
#  [ 7 89]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.47      0.61       109
#            1       0.61      0.93      0.73        96
#
#     accuracy                           0.68       205
#    macro avg       0.74      0.70      0.67       205
# weighted avg       0.75      0.68      0.67       205

# %%
from sklearn.model_selection import cross_val_score

# %%
print('LogisticRegression',cross_val_score(lr,p_c,y,cv=5).mean())
# Out:
# LogisticRegression 0.7004788268741583

# %% [markdown]
# # KNN

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model(knn,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  82.05546492659053

# %%
model(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  71.21951219512195
# [[76 33]
#  [26 70]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72       109
#            1       0.68      0.73      0.70        96
#
#     accuracy                           0.71       205
#    macro avg       0.71      0.71      0.71       205
# weighted avg       0.71      0.71      0.71       205

# %%
print('KNN',cross_val_score(knn,p_c,y,cv=5).mean())
# Out:
# KNN 0.718868771509801

# %% [markdown]
# # SVM

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
model(svc,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  75.04078303425776

# %%
model(svc,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  69.7560975609756
# [[54 55]
#  [ 7 89]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64       109
#            1       0.62      0.93      0.74        96
#
#     accuracy                           0.70       205
#    macro avg       0.75      0.71      0.69       205
# weighted avg       0.76      0.70      0.69       205

# %%
print('SVC',cross_val_score(svc,p_c,y,cv=5).mean())
# Out:
# SVC 0.6968801436480623

# %% [markdown]
# # DecisionTree Classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model(dt,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  99.673735725938

# %%
model(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  75.1219512195122
# [[84 25]
#  [26 70]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77       109
#            1       0.74      0.73      0.73        96
#
#     accuracy                           0.75       205
#    macro avg       0.75      0.75      0.75       205
# weighted avg       0.75      0.75      0.75       205

# %%
print('DecisionTreeClassifier',cross_val_score(dt,p_c,y,cv=5).mean())
# Out:
# DecisionTreeClassifier 0.7297845279066287

# %% [markdown]
# # RandomForestClassifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  99.673735725938

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  74.14634146341463
# [[81 28]
#  [25 71]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75       109
#            1       0.72      0.74      0.73        96
#
#     accuracy                           0.74       205
#    macro avg       0.74      0.74      0.74       205
# weighted avg       0.74      0.74      0.74       205

# %% [markdown]
# # Since Random Forest is the good model we will proceed for hyperparameter tuning

# %%
print('RandomForestClassifier',cross_val_score(rf,p_c,y,cv=5).mean())
# Out:
# RandomForestClassifier 0.7432664970821488

# %%
# Hyperparameter Tunnig
from sklearn.model_selection import GridSearchCV

# %%
params={'n_estimators':[100],
       'criterion':['gini','entropy'],
       'max_depth':[6,7,8,9],
       'min_samples_split':[4,5,6,7],
       'min_samples_leaf':[1,2,3,5]}

# %%
gv=GridSearchCV(rf,param_grid=params)
gv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 5],
#                          'min_samples_split': [4, 5, 6, 7],
#                          'n_estimators': [100]})

# %%
gv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
rf=RandomForestClassifier(criterion='gini',max_depth=9,min_samples_leaf=1,min_samples_split=5,n_estimators=100)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=9, min_samples_split=5)

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  95.10603588907016

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  76.09756097560975
# [[80 29]
#  [20 76]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.73      0.77       109
#            1       0.72      0.79      0.76        96
#
#     accuracy                           0.76       205
#    macro avg       0.76      0.76      0.76       205
# weighted avg       0.76      0.76      0.76       205

# %%
print('RandomForestClassifier',cross_val_score(rf,p_c,y,cv=5).mean())
# Out:
# RandomForestClassifier 0.7384034116414784

# %% [markdown]
# # Final Conclusion:-
#
# 1. Through Hyperparameter Tunning we have reduced the overfitting problem.
#
# 2. Accuracy Score for the model is 76%
#
# 3. F1 score is 77%
#
# 4. Cross_validation Score is 74%

# %%
plt.figure(figsize=(15,7))
disp=plot_roc_curve(lr,p_c,y)
plot_roc_curve(rf,p_c,y,ax=disp.ax_)
plot_roc_curve(svc,p_c,y,ax=disp.ax_)
plot_roc_curve(knn,p_c,y,ax=disp.ax_)
plot_roc_curve(dt,p_c,y,ax=disp.ax_)

# %%
y_pred=rf.predict(x_test)
Report=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
Report
# Out:
#      Actual  Predicted
# 657       0          0
# 520       1          1
# 732       0          0
# 779       0          0
# 20        0          0
# ..      ...        ...
# 798       0          1
# 405       0          0
# 397       1          0
# 62        0          0
# 665       0          1
#
# [205 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(y_test,y_pred,hue=y_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %%
## Saving the model
import pickle
filename='Loan_Report'
pickle.dump(rf,open(filename,'wb'))
