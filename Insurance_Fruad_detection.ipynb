# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('Automobile_insurance_fraud.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [5 rows x 40 columns]

# %%
df.shape
# Out:
# (1000, 40)

# %% [markdown]
# # Problem Statement:-
#
# Business case:
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
#
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
#
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %%
# Dropping _c39 as it has all null values
df.drop('_c39',axis=1,inplace=True)

# %%
df['police_report_available'].value_counts()
# Out:
# ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %%
df.groupby('police_report_available')['fraud_reported'].value_counts()
# Out:
# police_report_available  fraud_reported
# ?                        N                 254
#                          Y                  89
# NO                       N                 257
#                          Y                  86
# YES                      N                 242
#                          Y                  72
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # The ratio of Y and N is same for police report available or not,so replacing ? by No

# %%
df['police_report_available']=df['police_report_available'].replace('?','NO')

# %%
df['police_report_available'].value_counts()
# Out:
# NO     686
# YES    314
# Name: police_report_available, dtype: int64

# %%
cat=[]
for col in df:
    if df[col].dtype == 'object':
        cat.append(col)
print(cat)
# Out:
# ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']

# %%
for i in df[cat]:
    print(i)
    print(df[i].value_counts())
    
    print('#'*100)
# Out:
# policy_bind_date
# 01-01-2006    3
# 28-04-1992    3
# 05-08-1992    3
# 14-12-1991    2
# 09-08-2004    2
#              ..
# 03-06-2014    1
# 12-12-1998    1
# 18-02-1999    1
# 30-10-1997    1
# 11-11-1996    1
# Name: policy_bind_date, Length: 951, dtype: int64
# ####################################################################################################
# policy_state
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# ####################################################################################################
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64
# ####################################################################################################
# insured_sex
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64
# ####################################################################################################
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64
# ####################################################################################################
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64
# ####################################################################################################
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64
# ####################################################################################################
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64
# ####################################################################################################
# incident_date
# 02-02-2015    28
# 17-02-2015    26
# 07-01-2015    25
# 10-01-2015    24
# 04-02-2015    24
# 24-01-2015    24
# 19-01-2015    23
# 08-01-2015    22
# 13-01-2015    21
# 30-01-2015    21
# 12-02-2015    20
# 22-02-2015    20
# 31-01-2015    20
# 06-02-2015    20
# 21-02-2015    19
# 01-01-2015    19
# 23-02-2015    19
# 12-01-2015    19
# 14-01-2015    19
# 21-01-2015    19
# 03-01-2015    18
# 14-02-2015    18
# 01-02-2015    18
# 28-02-2015    18
# 20-01-2015    18
# 18-01-2015    18
# 25-02-2015    18
# 06-01-2015    17
# 09-01-2015    17
# 08-02-2015    17
# 24-02-2015    17
# 26-02-2015    17
# 13-02-2015    16
# 15-02-2015    16
# 16-02-2015    16
# 05-02-2015    16
# 16-01-2015    16
# 17-01-2015    15
# 18-02-2015    15
# 28-01-2015    15
# 15-01-2015    15
# 22-01-2015    14
# 20-02-2015    14
# 27-02-2015    14
# 23-01-2015    13
# 03-02-2015    13
# 27-01-2015    13
# 09-02-2015    13
# 04-01-2015    12
# 01-03-2015    12
# 26-01-2015    11
# 29-01-2015    11
# 02-01-2015    11
# 19-02-2015    10
# 11-02-2015    10
# 10-02-2015    10
# 07-02-2015    10
# 25-01-2015    10
# 11-01-2015     9
# 05-01-2015     7
# Name: incident_date, dtype: int64
# ####################################################################################################
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64
# ####################################################################################################
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64
# ####################################################################################################
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64
# ####################################################################################################
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64
# ####################################################################################################
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64
# ####################################################################################################
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64
# ####################################################################################################
# incident_location
# 9935 4th Drive         1
# 4214 MLK Ridge         1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
#                       ..
# 6770 1st St            1
# 4119 Texas St          1
# 4347 2nd Ridge         1
# 1091 1st Drive         1
# 1416 Cherokee Ridge    1
# Name: incident_location, Length: 1000, dtype: int64
# ####################################################################################################
# property_damage
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64
# ####################################################################################################
# police_report_available
# NO     686
# YES    314
# Name: police_report_available, dtype: int64
# ####################################################################################################
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64
# ####################################################################################################
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64
# ####################################################################################################
# fraud_reported
# N    753
# Y    247
# Name: fraud_reported, dtype: int64
# ####################################################################################################

# %%
df.groupby('incident_type')['collision_type'].value_counts()
# Out:
# incident_type             collision_type
# Multi-vehicle Collision   Rear Collision     152
#                           Side Collision     152
#                           Front Collision    115
# Parked Car                ?                   84
# Single Vehicle Collision  Rear Collision     140
#                           Front Collision    139
#                           Side Collision     124
# Vehicle Theft             ?                   94
# Name: collision_type, dtype: int64

# %% [markdown]
# # Clearly missing value in collision type is for parked car and Vehicle Theft,so we can replace by No Collision

# %%
df['collision_type']=df['collision_type'].replace('?','No Collision')

# %%
# Lets check property damage
df.groupby('property_damage')['incident_severity'].value_counts()
# Out:
# property_damage  incident_severity
# ?                Major Damage         115
#                  Minor Damage         110
#                  Total Loss            97
#                  Trivial Damage        38
# NO               Minor Damage         135
#                  Total Loss            98
#                  Major Damage          74
#                  Trivial Damage        31
# YES              Minor Damage         109
#                  Major Damage          87
#                  Total Loss            85
#                  Trivial Damage        21
# Name: incident_severity, dtype: int64

# %% [markdown]
# # Since we cannot conclude the property damage by Incident Severity.So we can replace by padding

# %%
df['property_damage']=df['property_damage'].replace('?',np.nan)
df['property_damage'].isna().sum()
# Out:
# 360

# %%
df['property_damage']=df['property_damage'].fillna(method='pad')

# %%
df['property_damage'].value_counts()
# Out:
# NO     521
# YES    479
# Name: property_damage, dtype: int64

# %% [markdown]
# # EDA

# %%
df.describe().T
# Out:
#                               count          mean           std         min  \
# months_as_customer           1000.0  2.039540e+02  1.151132e+02        0.00
# age                          1000.0  3.894800e+01  9.140287e+00       19.00
# policy_number                1000.0  5.462386e+05  2.570630e+05   100804.00
# policy_deductable            1000.0  1.136000e+03  6.118647e+02      500.00
# policy_annual_premium        1000.0  1.256406e+03  2.441674e+02      433.33
# umbrella_limit               1000.0  1.101000e+06  2.297407e+06 -1000000.00
# insured_zip                  1000.0  5.012145e+05  7.170161e+04   430104.00
# capital-gains                1000.0  2.512610e+04  2.787219e+04        0.00
# capital-loss                 1000.0 -2.679370e+04  2.810410e+04  -111100.00
# incident_hour_of_the_day     1000.0  1.164400e+01  6.951373e+00        0.00
# number_of_vehicles_involved  1000.0  1.839000e+00  1.018880e+00        1.00
# bodily_injuries              1000.0  9.920000e-01  8.201272e-01        0.00
# witnesses                    1000.0  1.487000e+00  1.111335e+00        0.00
# total_claim_amount           1000.0  5.276194e+04  2.640153e+04      100.00
# injury_claim                 1000.0  7.433420e+03  4.880952e+03        0.00
# property_claim               1000.0  7.399570e+03  4.824726e+03        0.00
# vehicle_claim                1000.0  3.792895e+04  1.888625e+04       70.00
# auto_year                    1000.0  2.005103e+03  6.015861e+00     1995.00
#
#                                      25%       50%         75%          max
# months_as_customer              115.7500     199.5     276.250       479.00
# age                              32.0000      38.0      44.000        64.00
# policy_number                335980.2500  533135.0  759099.750    999435.00
# policy_deductable               500.0000    1000.0    2000.000      2000.00
# policy_annual_premium          1089.6075    1257.2    1415.695      2047.59
# umbrella_limit                    0.0000       0.0       0.000  10000000.00
# insured_zip                  448404.5000  466445.5  603251.000    620962.00
# capital-gains                     0.0000       0.0   51025.000    100500.00
# capital-loss                 -51500.0000  -23250.0       0.000         0.00
# incident_hour_of_the_day          6.0000      12.0      17.000        23.00
# number_of_vehicles_involved       1.0000       1.0       3.000         4.00
# bodily_injuries                   0.0000       1.0       2.000         2.00
# witnesses                         1.0000       1.0       2.000         3.00
# total_claim_amount            41812.5000   58055.0   70592.500    114920.00
# injury_claim                   4295.0000    6775.0   11305.000     21450.00
# property_claim                 4445.0000    6750.0   10885.000     23670.00
# vehicle_claim                 30292.5000   42100.0   50822.500     79560.00
# auto_year                      2000.0000    2005.0    2010.000      2015.00

# %%
df.nunique().to_frame()
# Out:
#                                 0
# months_as_customer            391
# age                            46
# policy_number                1000
# policy_bind_date              951
# policy_state                    3
# policy_csl                      3
# policy_deductable               3
# policy_annual_premium         991
# umbrella_limit                 11
# insured_zip                   995
# insured_sex                     2
# insured_education_level         7
# insured_occupation             14
# insured_hobbies                20
# insured_relationship            6
# capital-gains                 338
# capital-loss                  354
# incident_date                  60
# incident_type                   4
# collision_type                  4
# incident_severity               4
# authorities_contacted           5
# incident_state                  7
# incident_city                   7
# incident_location            1000
# incident_hour_of_the_day       24
# number_of_vehicles_involved     4
# property_damage                 2
# bodily_injuries                 3
# witnesses                       4
# police_report_available         2
# total_claim_amount            763
# injury_claim                  638
# property_claim                626
# vehicle_claim                 726
# auto_make                      14
# auto_model                     39
# auto_year                      21
# fraud_reported                  2

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.describe().T,annot=True,annot_kws={'size':10},fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[cat]
# Out:
#     policy_bind_date policy_state policy_csl insured_sex  \
# 0         17-10-2014           OH    250/500        MALE
# 1         27-06-2006           IN    250/500        MALE
# 2         06-09-2000           OH    100/300      FEMALE
# 3         25-05-1990           IL    250/500      FEMALE
# 4         06-06-2014           IL   500/1000        MALE
# ..               ...          ...        ...         ...
# 995       16-07-1991           OH   500/1000      FEMALE
# 996       05-01-2014           IL    100/300      FEMALE
# 997       17-02-2003           OH    250/500      FEMALE
# 998       18-11-2011           IL   500/1000        MALE
# 999       11-11-1996           OH    250/500      FEMALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        MD       craft-repair        sleeping
# 1                        MD  machine-op-inspct         reading
# 2                       PhD              sales     board-games
# 3                       PhD       armed-forces     board-games
# 4                 Associate              sales     board-games
# ..                      ...                ...             ...
# 995                 Masters       craft-repair       paintball
# 996                     PhD     prof-specialty        sleeping
# 997                 Masters       armed-forces  bungie-jumping
# 998               Associate  handlers-cleaners    base-jumping
# 999               Associate              sales        kayaking
#
#     insured_relationship incident_date             incident_type  ...  \
# 0                husband    25-01-2015  Single Vehicle Collision  ...
# 1         other-relative    21-01-2015             Vehicle Theft  ...
# 2              own-child    22-02-2015   Multi-vehicle Collision  ...
# 3              unmarried    10-01-2015  Single Vehicle Collision  ...
# 4              unmarried    17-02-2015             Vehicle Theft  ...
# ..                   ...           ...                       ...  ...
# 995            unmarried    22-02-2015  Single Vehicle Collision  ...
# 996                 wife    24-01-2015  Single Vehicle Collision  ...
# 997       other-relative    23-01-2015   Multi-vehicle Collision  ...
# 998                 wife    26-02-2015  Single Vehicle Collision  ...
# 999              husband    26-02-2015                Parked Car  ...
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 2        Minor Damage                Police             NY      Columbus
# 3        Major Damage                Police             OH     Arlington
# 4        Minor Damage                  None             NY     Arlington
# ..                ...                   ...            ...           ...
# 995      Minor Damage                  Fire             NC    Northbrook
# 996      Major Damage                  Fire             SC     Northbend
# 997      Minor Damage                Police             NC     Arlington
# 998      Major Damage                 Other             NY     Arlington
# 999      Minor Damage                Police             WV      Columbus
#
#        incident_location property_damage police_report_available   auto_make  \
# 0         9935 4th Drive             YES                     YES        Saab
# 1           6608 MLK Hwy             YES                      NO    Mercedes
# 2      7121 Francis Lane              NO                      NO       Dodge
# 3       6956 Maple Drive              NO                      NO   Chevrolet
# 4           3041 3rd Ave              NO                      NO      Accura
# ..                   ...             ...                     ...         ...
# 995   6045 Andromedia St             YES                      NO       Honda
# 996     3092 Texas Drive             YES                      NO  Volkswagen
# 997          7629 5th St             YES                     YES      Suburu
# 998        6128 Elm Lane             YES                     YES        Audi
# 999  1416 Cherokee Ridge             YES                      NO    Mercedes
#
#     auto_model fraud_reported
# 0          92x              Y
# 1         E400              Y
# 2          RAM              N
# 3        Tahoe              Y
# 4          RSX              N
# ..         ...            ...
# 995     Accord              N
# 996     Passat              N
# 997    Impreza              N
# 998         A5              N
# 999       E400              N
#
# [1000 rows x 21 columns]

# %%
df.drop(columns=['policy_bind_date','policy_number'],axis=1,inplace=True)

# %%
df
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                  1406.91               0       466132        MALE
# 1                  1197.22         5000000       468176        MALE
# 2                  1413.14         5000000       430632      FEMALE
# 3                  1415.74         6000000       608117      FEMALE
# 4                  1583.91         6000000       610706        MALE
# ..                     ...             ...          ...         ...
# 995                1310.80               0       431289      FEMALE
# 996                1436.79               0       608177      FEMALE
# 997                1383.49         3000000       442797      FEMALE
# 998                1356.92         5000000       441714        MALE
# 999                 766.19               0       612260      FEMALE
#
#     insured_education_level  ... witnesses police_report_available  \
# 0                        MD  ...         2                     YES
# 1                        MD  ...         0                      NO
# 2                       PhD  ...         3                      NO
# 3                       PhD  ...         2                      NO
# 4                 Associate  ...         1                      NO
# ..                      ...  ...       ...                     ...
# 995                 Masters  ...         1                      NO
# 996                     PhD  ...         3                      NO
# 997                 Masters  ...         3                     YES
# 998               Associate  ...         1                     YES
# 999               Associate  ...         3                      NO
#
#     total_claim_amount  injury_claim  property_claim vehicle_claim  \
# 0                71610          6510           13020         52080
# 1                 5070           780             780          3510
# 2                34650          7700            3850         23100
# 3                63400          6340            6340         50720
# 4                 6500          1300             650          4550
# ..                 ...           ...             ...           ...
# 995              87200         17440            8720         61040
# 996             108480         18080           18080         72320
# 997              67500          7500            7500         52500
# 998              46980          5220            5220         36540
# 999               5060           460             920          3680
#
#       auto_make auto_model auto_year fraud_reported
# 0          Saab        92x      2004              Y
# 1      Mercedes       E400      2007              Y
# 2         Dodge        RAM      2007              N
# 3     Chevrolet      Tahoe      2014              Y
# 4        Accura        RSX      2009              N
# ..          ...        ...       ...            ...
# 995       Honda     Accord      2006              N
# 996  Volkswagen     Passat      2015              N
# 997      Suburu    Impreza      1996              N
# 998        Audi         A5      1998              N
# 999    Mercedes       E400      2007              N
#
# [1000 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,7))
sns.countplot('age',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(10,7))
sns.countplot('policy_state',data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot('policy_csl',data=df)
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.countplot('insured_sex',data=df)
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
plt.pie(df['insured_occupation'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['insured_occupation'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['incident_type'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['incident_type'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['collision_type'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['collision_type'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['incident_severity'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['incident_severity'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['authorities_contacted'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['authorities_contacted'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['incident_state'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['incident_state'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['incident_city'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['incident_city'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['property_damage'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['property_damage'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['bodily_injuries'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['bodily_injuries'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(df['witnesses'].value_counts(),autopct='%1.2f%%',shadow=True,labels=df['witnesses'].unique())
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot('police_report_available',data=df)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.countplot('auto_make',data=df)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot('auto_model',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot('fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
df.hist(figsize=(15,30),edgecolor='red',layout=(9,3),legend=True)
plt.show()

# %% [markdown]
# # Observation Of Univariate:-
#
# 1. Age between 28 to 47 has high rate of frequency who having automobile insurance.
#
# 2. Policy_state OH having high frequency than others.
#
# 3. Policy_Csl 250/500 and 100/500 has equal frequency.
#
# 4. Female has high frequency of having insurance than male. High school graduate having high frequency in the data.
#
# 5. Police Complaint registerted has high frequency with No.
#
# 6. The fraud reported has less value with yes than No. so the class is imbalance.
#
# 7. Month as customer between 100 to 300 has high frequency of holding automobile insurance policy.
#
# 8. Policy deductible has 1000 and 2000 with high frequency.
#
# 9. Premium lies between 1000 to 1500 has high frequency.
#
# 10. Umberalla lime i.e extra coverage has high frequency of 0 value.
#
# 11. Insured_zip has high value of 400000 and 0.
#
# 12. Capital Gain and capital loss has high value of 0.
#
# 13. Total claim amount lies between 40000 to 80000 has high frequency

# %% [markdown]
# # Bivariate Analysis

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='fraud_reported',y='months_as_customer',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='months_as_customer'>

# %% [markdown]
# ## Observation:- Month is high then the chance of fraud claim high

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='fraud_reported',y='age',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='age'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='policy_state',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %% [markdown]
# # Observation:- doest show any significance difference

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='policy_csl',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='count'>

# %% [markdown]
# ### Observation:- 250/500 and 100/300 high rate of fraud claim done

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='fraud_reported',y='policy_deductable',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='policy_deductable'>

# %% [markdown]
# ### Observation:- Deductible amount does not show significance difference

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='fraud_reported',y='policy_annual_premium',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='policy_annual_premium'>

# %% [markdown]
# ### Observation :- As we tends towards higher premium the fraud claim rate decreases

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='umbrella_limit',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='umbrella_limit'>

# %% [markdown]
# ### Observation:- Higher umbrella limit has high case of fraud claim rate

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='insured_zip',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='insured_zip'>

# %% [markdown]
# ### Observation:- Not much difference shows from insured_zip

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='insured_sex',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %% [markdown]
# ### Observation:- Compared to female male has high rate of fraud claim.

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='insured_occupation',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Observation:- Exec managrial seems to have reported more fraud claim.

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='insured_hobbies',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- The person having hobbies of playing chess and cross-fit has high frequency of fraud-claim

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='insured_relationship',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- Other relative has high fraud claim rate

# %%
plt.figure(figsize=(10,7))
sns.bareplot(x='fraud_reported',y='capital-gains',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5807/3787815860.py in <module>
#       1 plt.figure(figsize=(10,7))
# ----> 2 sns.bareplot(x='fraud_reported',y='capital-gains',data=df)
#
# AttributeError: module 'seaborn' has no attribute 'bareplot'

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='fraud_reported',y='capital-loss',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='capital-loss'>

# %% [markdown]
# ### Observation:- If the capital gain is more the frequency of fraud rate decreases and if the capital loss more then fraud rate increases.

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='incident_type',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- Not much difference can be analysed from this graph

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='incident_severity',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- For major damage case the rate of fraud claim rate also increases

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='authorities_contacted',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- In case of fire other and ambulance the authority contacted having high rate of fraud insurance claim

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='incident_state',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- The SC state has high rate of insurance fraud

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='incident_city',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- Arlington city has high rate of insurance fraud claim rate than others.

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='fraud_reported',y='incident_hour_of_the_day',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='incident_hour_of_the_day'>

# %% [markdown]
# ### Observation:- The plot does not show relation between fraud and actual claim

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='number_of_vehicles_involved',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='number_of_vehicles_involved'>

# %% [markdown]
# ### Observation:- The Number of vechile involved goes higher the fraud rate increases.

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='total_claim_amount',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %% [markdown]
# ### Observation:- If the claim amount increases the Fraud claim rate also increases

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='injury_claim',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='injury_claim'>

# %% [markdown]
# ### Observation:- The claim amount increases the fraud rate also increases

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='property_claim',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='property_claim'>

# %% [markdown]
# ### Observation:- The property claim amount increases the claim rate also increases

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='vehicle_claim',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='vehicle_claim'>

# %% [markdown]
# ### Observation:- Similarly the vehicle claim amount increases the fraud claim rate increases

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='fraud_reported',y='witnesses',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='witnesses'>

# %% [markdown]
# ### Observation:- The number witness increases the fraud rate of claim increases

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x='fraud_reported',y='auto_year',data=df)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='auto_year'>

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='property_damage',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- The if property damage case is there, it has high chance of fraud claim rate

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='bodily_injuries',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:-If the value of 2 bodily injured the fraud claim rate also increases

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='auto_make',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- The graph shows Mercedes,chevrolet,Audi,Ford having high fraud claim rate

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='auto_model',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- RAM model has high rate of fraud

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='police_report_available',hue='fraud_reported',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Observation:- The police report does not show any significance difference

# %%
df
# Out:
#      months_as_customer  age policy_state policy_csl  policy_deductable  \
# 0                   328   48           OH    250/500               1000
# 1                   228   42           IN    250/500               2000
# 2                   134   29           OH    100/300               2000
# 3                   256   41           IL    250/500               2000
# 4                   228   44           IL   500/1000               1000
# ..                  ...  ...          ...        ...                ...
# 995                   3   38           OH   500/1000               1000
# 996                 285   41           IL    100/300               1000
# 997                 130   34           OH    250/500                500
# 998                 458   62           IL   500/1000               2000
# 999                 456   60           OH    250/500               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip insured_sex  \
# 0                  1406.91               0       466132        MALE
# 1                  1197.22         5000000       468176        MALE
# 2                  1413.14         5000000       430632      FEMALE
# 3                  1415.74         6000000       608117      FEMALE
# 4                  1583.91         6000000       610706        MALE
# ..                     ...             ...          ...         ...
# 995                1310.80               0       431289      FEMALE
# 996                1436.79               0       608177      FEMALE
# 997                1383.49         3000000       442797      FEMALE
# 998                1356.92         5000000       441714        MALE
# 999                 766.19               0       612260      FEMALE
#
#     insured_education_level  ... witnesses police_report_available  \
# 0                        MD  ...         2                     YES
# 1                        MD  ...         0                      NO
# 2                       PhD  ...         3                      NO
# 3                       PhD  ...         2                      NO
# 4                 Associate  ...         1                      NO
# ..                      ...  ...       ...                     ...
# 995                 Masters  ...         1                      NO
# 996                     PhD  ...         3                      NO
# 997                 Masters  ...         3                     YES
# 998               Associate  ...         1                     YES
# 999               Associate  ...         3                      NO
#
#     total_claim_amount  injury_claim  property_claim vehicle_claim  \
# 0                71610          6510           13020         52080
# 1                 5070           780             780          3510
# 2                34650          7700            3850         23100
# 3                63400          6340            6340         50720
# 4                 6500          1300             650          4550
# ..                 ...           ...             ...           ...
# 995              87200         17440            8720         61040
# 996             108480         18080           18080         72320
# 997              67500          7500            7500         52500
# 998              46980          5220            5220         36540
# 999               5060           460             920          3680
#
#       auto_make auto_model auto_year fraud_reported
# 0          Saab        92x      2004              Y
# 1      Mercedes       E400      2007              Y
# 2         Dodge        RAM      2007              N
# 3     Chevrolet      Tahoe      2014              Y
# 4        Accura        RSX      2009              N
# ..          ...        ...       ...            ...
# 995       Honda     Accord      2006              N
# 996  Volkswagen     Passat      2015              N
# 997      Suburu    Impreza      1996              N
# 998        Audi         A5      1998              N
# 999    Mercedes       E400      2007              N
#
# [1000 rows x 37 columns]

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.drop(columns=['incident_date','auto_year','incident_location'],axis=1,inplace=True)

# %%
df.drop('auto_model',axis=1,inplace=True)

# %%
df[['fraud_reported','police_report_available','property_damage','incident_city','incident_state','authorities_contacted',
    'incident_severity','collision_type','incident_type','insured_relationship','insured_hobbies','insured_occupation','insured_education_level',
   'insured_sex','policy_csl','policy_state','auto_make']]=df[['fraud_reported','police_report_available','property_damage','incident_city','incident_state','authorities_contacted',
    'incident_severity','collision_type','incident_type','insured_relationship','insured_hobbies','insured_occupation','insured_education_level',
   'insured_sex','policy_csl','policy_state','auto_make']].apply(le.fit_transform)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_state                 1000 non-null   int64
#  3   policy_csl                   1000 non-null   int64
#  4   policy_deductable            1000 non-null   int64
#  5   policy_annual_premium        1000 non-null   float64
#  6   umbrella_limit               1000 non-null   int64
#  7   insured_zip                  1000 non-null   int64
#  8   insured_sex                  1000 non-null   int64
#  9   insured_education_level      1000 non-null   int64
#  10  insured_occupation           1000 non-null   int64
#  11  insured_hobbies              1000 non-null   int64
#  12  insured_relationship         1000 non-null   int64
#  13  capital-gains                1000 non-null   int64
#  14  capital-loss                 1000 non-null   int64
#  15  incident_type                1000 non-null   int64
#  16  collision_type               1000 non-null   int64
#  17  incident_severity            1000 non-null   int64
#  18  authorities_contacted        1000 non-null   int64
#  19  incident_state               1000 non-null   int64
#  20  incident_city                1000 non-null   int64
#  21  incident_hour_of_the_day     1000 non-null   int64
#  22  number_of_vehicles_involved  1000 non-null   int64
#  23  property_damage              1000 non-null   int64
#  24  bodily_injuries              1000 non-null   int64
#  25  witnesses                    1000 non-null   int64
#  26  police_report_available      1000 non-null   int64
#  27  total_claim_amount           1000 non-null   int64
#  28  injury_claim                 1000 non-null   int64
#  29  property_claim               1000 non-null   int64
#  30  vehicle_claim                1000 non-null   int64
#  31  auto_make                    1000 non-null   int64
#  32  fraud_reported               1000 non-null   int64
# dtypes: float64(1), int64(32)
# memory usage: 257.9 KB

# %%
plt.figure(figsize=(25,25),facecolor='lightyellow')

plotnumber=1
for column in df:
    if plotnumber <= 36:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(df[column],kde=True,color='red')
        plt.xlabel(column,fontsize=16)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %% [markdown]
# ### Observation:- Clearly some skewness is there

# %%
plt.figure(figsize=(25,25),facecolor='lightyellow')

plotnumber=1
for column in df:
    if plotnumber <= 36:
        ax=plt.subplot(6,6,plotnumber)
        sns.boxplot(df[column],color='violet')
        plt.xlabel(column,fontsize=16)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
# We will remove outlier through zscore.
from scipy.stats import zscore
df.shape
# Out:
# (1000, 33)

# %%
df=df[np.abs(zscore(df)<3).all(axis=1)]

# %%
df.shape
# Out:
# (983, 33)

# %%
percent_loss=print((17/1000)*100)
# Out:
# 1.7000000000000002

# %% [markdown]
# ### Just 1.7 percent data loss through zscore

# %%
plt.figure(figsize=(25,25),facecolor='lightyellow')

plotnumber=1
for column in df:
    if plotnumber <= 36:
        ax=plt.subplot(6,6,plotnumber)
        sns.boxplot(df[column],color='orange')
        plt.xlabel(column,fontsize=16)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
df.skew()
# Out:
# months_as_customer             0.366303
# age                            0.478261
# policy_state                  -0.036113
# policy_csl                     0.096017
# policy_deductable              0.475798
# policy_annual_premium         -0.017987
# umbrella_limit                 1.806345
# insured_zip                    0.831511
# insured_sex                    0.140949
# insured_education_level        0.006218
# insured_occupation            -0.056178
# insured_hobbies               -0.061328
# insured_relationship           0.075774
# capital-gains                  0.466842
# capital-loss                  -0.389587
# incident_type                  0.094891
# collision_type                -0.176234
# incident_severity              0.280436
# authorities_contacted         -0.110122
# incident_state                -0.149207
# incident_city                  0.045063
# incident_hour_of_the_day      -0.034787
# number_of_vehicles_involved    0.505944
# property_damage                0.083618
# bodily_injuries                0.005622
# witnesses                      0.021612
# police_report_available        0.795943
# total_claim_amount            -0.594422
# injury_claim                   0.268453
# property_claim                 0.357089
# vehicle_claim                 -0.621070
# auto_make                     -0.028824
# fraud_reported                 1.186563
# dtype: float64

# %% [markdown]
# ### Observation:- Skewness in some of the features found.

# %%
# Lets Separate target and features 
X=df.drop('fraud_reported',axis=1)
y=df.fraud_reported

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
X=pd.DataFrame(pt.fit_transform(X),columns=X.columns)

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X,y=sm.fit_resample(X,y)

# %%
X.skew()
# Out:
# months_as_customer            -0.124107
# age                            0.019184
# policy_state                  -0.226075
# policy_csl                    -0.116211
# policy_deductable              0.016594
# policy_annual_premium         -0.003025
# umbrella_limit                -6.876498
# insured_zip                    0.000000
# insured_sex                    0.086070
# insured_education_level       -0.184908
# insured_occupation            -0.177045
# insured_hobbies               -0.156364
# insured_relationship          -0.215197
# capital-gains                  0.081878
# capital-loss                   0.046059
# incident_type                 -0.154506
# collision_type                -0.321436
# incident_severity              0.274308
# authorities_contacted         -0.167905
# incident_state                -0.251643
# incident_city                 -0.197736
# incident_hour_of_the_day      -0.312574
# number_of_vehicles_involved    0.378241
# property_damage                0.037385
# bodily_injuries               -0.167385
# witnesses                     -0.251328
# police_report_available        0.852136
# total_claim_amount            -0.715131
# injury_claim                  -0.556265
# property_claim                -0.500063
# vehicle_claim                 -0.724658
# auto_make                     -0.145018
# dtype: float64

# %%
plt.figure(figsize=(25,25),facecolor='lightyellow')

plotnumber=1
for column in X:
    if plotnumber <= 36:
        ax=plt.subplot(6,6,plotnumber)
        sns.kdeplot(X[column],color='red')
        plt.xlabel(column,fontsize=16)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
plt.figure(figsize=(35,35))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':10},linewidths=8)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
X.corrwith(y).sort_values(ascending=False).plot(kind='bar',grid=True,title='Correlation with Target')
# Out:
# <AxesSubplot:title={'center':'Correlation with Target'}>

# %% [markdown]
# ## Observation:- Some features dont have any relation with target. By performing PCA we can overcome this

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=scaler.fit_transform(X)

# %%
x
# Out:
# array([[ 1.06420352,  1.02573553,  1.14804361, ...,  1.0764095 ,
#          0.70179567,  0.93102876],
#        [ 0.28728746,  0.4331072 ,  0.01885402, ..., -1.77727327,
#         -2.04438042,  0.46426634],
#        [-0.5626337 , -1.18000436,  1.14804361, ..., -0.72180448,
#         -1.00061966, -0.56488055],
#        ...,
#        [ 0.42622849,  0.71827306, -1.24085607, ..., -0.16330658,
#         -0.23958515,  1.37594519],
#        [ 0.28779862,  0.17773996, -1.24141908, ...,  1.312844  ,
#          1.05702304,  0.13646402],
#        [ 1.75389124,  1.77921365,  0.71154531, ...,  0.3297992 ,
#          0.30036165, -0.04478127]])

# %%
from sklearn.decomposition import PCA
pca=PCA()

# %%
pca.fit_transform(x)
# Out:
# array([[-8.25040718e-01,  1.43274214e+00, -6.76652233e-01, ...,
#          4.85788352e-02,  5.74129148e-02,  1.59466374e-03],
#        [ 4.30700665e+00,  5.72732988e-01, -2.24876429e-01, ...,
#          1.25268993e-01, -4.10806946e-01,  3.80558182e-02],
#        [ 8.46126398e-01, -1.45149555e+00,  1.54206460e+00, ...,
#         -4.49550822e-01, -1.12877427e-01, -4.24602603e-02],
#        ...,
#        [-1.17836610e+00,  3.51698450e-01,  1.83929073e+00, ...,
#          1.42159866e-01, -5.15959289e-02,  9.48161054e-03],
#        [-3.10756936e+00,  4.53732800e-01,  9.51236018e-01, ...,
#         -1.80412424e-01,  7.39521103e-03,  9.48003037e-02],
#        [ 2.92739788e-01,  3.18046311e+00,  9.14411342e-02, ...,
#          1.64156042e-02, -4.12713215e-02, -5.83635451e-02]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('features')
plt.ylabel('Variance Covered')
plt.title('PCA')
# Out:
# Text(0.5, 1.0, 'PCA')

# %% [markdown]
# # Observation:- Since 27 components explained maximum variance of dataset so we can assume 27 components to give best result

# %%
pca=PCA(n_components=27)
pcomp=pca.fit_transform(x)
pc=pd.DataFrame(pcomp,columns=['PC'+str(i) for i in range(1,28)])

# %%
pc
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.825041  1.432742 -0.676652  1.209296  1.270667  1.390366  1.393037
# 1     4.307007  0.572733 -0.224876 -0.307915 -0.087557  0.234368  0.121791
# 2     0.846126 -1.451496  1.542065 -0.771120 -0.191506 -1.839649 -0.018103
# 3     0.338904  1.589187 -0.077237 -0.910736  0.953451  0.435863 -1.293573
# 4     3.822419  1.601659  0.572733 -1.147235 -0.118732 -0.768027 -1.385397
# ...        ...       ...       ...       ...       ...       ...       ...
# 1479 -0.561124  0.480648 -1.591732 -0.792597  0.350689  1.540017  0.644339
# 1480 -3.311686 -0.130101  0.133756 -0.620858 -2.543643 -0.947730 -0.486094
# 1481 -1.178366  0.351698  1.839291  0.052984 -1.529178 -0.533608  0.626588
# 1482 -3.107569  0.453733  0.951236  0.831907 -1.491527  0.234428 -0.775762
# 1483  0.292740  3.180463  0.091441  0.400626 -1.772854 -0.246483 -0.776622
#
#            PC8       PC9      PC10  ...      PC18      PC19      PC20  \
# 0    -0.829848  0.882994  1.403168  ... -0.114663 -0.804943 -0.780677
# 1    -0.541462  1.221806  0.563684  ... -1.784759 -0.725509 -0.630511
# 2    -0.846071 -2.188977  0.107698  ...  0.224305  0.752117 -2.461086
# 3    -2.572906 -2.182951 -1.141758  ... -0.001421 -0.498432  0.705631
# 4     1.996743 -0.171059 -2.109827  ...  0.595724 -1.242965  0.881584
# ...        ...       ...       ...  ...       ...       ...       ...
# 1479 -0.345048 -0.205829  1.586382  ... -0.090139  1.623647  0.528481
# 1480 -0.325493 -0.747088  0.203991  ...  0.462264  1.014568 -1.467958
# 1481 -0.303703  0.871422 -1.049129  ... -0.405457 -0.912260 -0.026107
# 1482 -0.193846  0.204686 -0.700843  ...  0.338644 -1.084407  1.419310
# 1483  1.282504 -0.907277 -0.563698  ... -0.311517 -0.432463  1.127647
#
#           PC21      PC22      PC23      PC24      PC25      PC26      PC27
# 0    -0.134520  0.441708 -1.030157 -0.977820  0.237320 -0.858927 -0.005760
# 1    -0.033335  0.505808  0.423881  0.616261 -1.379613  0.515069 -0.527604
# 2     1.782550  0.007277  0.090015  0.197762 -0.347885 -1.285354  0.872801
# 3    -0.624483  0.048501 -1.150510  0.015188 -0.154885 -0.823384  2.029079
# 4    -1.098285 -1.418000  0.185954 -1.631418 -0.055058  0.524606  1.757698
# ...        ...       ...       ...       ...       ...       ...       ...
# 1479 -0.402731 -0.178858  0.777095 -1.427681 -0.404806 -1.009674 -0.738032
# 1480 -0.130869 -0.596071 -1.521213 -0.046282 -1.457620 -0.142013  0.205371
# 1481  1.547263 -0.376153 -1.478029 -0.697422  0.523024 -0.456850  0.769388
# 1482 -0.083832  0.971299  0.989837  0.263263 -0.073504 -0.109779  0.754936
# 1483 -0.948060  0.196397  0.294259 -0.218289  1.468058  0.167475 -0.315663
#
# [1484 rows x 27 columns]

# %%
## Model building

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,plot_roc_curve

# %%
# Logistic Regression
lr=LogisticRegression()

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(pc,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    ypred=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    if round(accuracy_score(y_train,ypred)*100)==round(accuracy_score(y_test,y_pred)*100):
        print('At random state',i,'model performs well')
        print('At random state ',i)
        print(round(accuracy_score(y_test,y_pred)*100))
# Out:
# At random state 3 model performs well
# At random state  3
# 75
# At random state 4 model performs well
# At random state  4
# 76
# At random state 6 model performs well
# At random state  6
# 75
# At random state 34 model performs well
# At random state  34
# 76
# At random state 38 model performs well
# At random state  38
# 75
# At random state 59 model performs well
# At random state  59
# 75
# At random state 84 model performs well
# At random state  84
# 76
# At random state 106 model performs well
# At random state  106
# 75
# At random state 113 model performs well
# At random state  113
# 76
# At random state 118 model performs well
# At random state  118
# 75
# At random state 119 model performs well
# At random state  119
# 75
# At random state 121 model performs well
# At random state  121
# 76
# At random state 142 model performs well
# At random state  142
# 74
# At random state 146 model performs well
# At random state  146
# 76
# At random state 156 model performs well
# At random state  156
# 75
# At random state 158 model performs well
# At random state  158
# 76
# At random state 175 model performs well
# At random state  175
# 75
# At random state 241 model performs well
# At random state  241
# 75
# At random state 260 model performs well
# At random state  260
# 75
# At random state 280 model performs well
# At random state  280
# 75
# At random state 283 model performs well
# At random state  283
# 76
# At random state 287 model performs well
# At random state  287
# 75
# At random state 288 model performs well
# At random state  288
# 75
# At random state 289 model performs well
# At random state  289
# 75
# At random state 292 model performs well
# At random state  292
# 75
# At random state 294 model performs well
# At random state  294
# 75
# At random state 300 model performs well
# At random state  300
# 76
# At random state 302 model performs well
# At random state  302
# 75
# At random state 303 model performs well
# At random state  303
# 76
# At random state 308 model performs well
# At random state  308
# 76
# At random state 331 model performs well
# At random state  331
# 75
# At random state 341 model performs well
# At random state  341
# 75
# At random state 348 model performs well
# At random state  348
# 75
# At random state 357 model performs well
# At random state  357
# 75
# At random state 360 model performs well
# At random state  360
# 75
# At random state 375 model performs well
# At random state  375
# 76
# At random state 379 model performs well
# At random state  379
# 75
# At random state 380 model performs well
# At random state  380
# 76
# At random state 384 model performs well
# At random state  384
# 75
# At random state 385 model performs well
# At random state  385
# 76
# At random state 388 model performs well
# At random state  388
# 75
# At random state 389 model performs well
# At random state  389
# 76
# At random state 390 model performs well
# At random state  390
# 76
# At random state 393 model performs well
# At random state  393
# 75
# At random state 400 model performs well
# At random state  400
# 76
# At random state 403 model performs well
# At random state  403
# 76
# At random state 412 model performs well
# At random state  412
# 75
# At random state 429 model performs well
# At random state  429
# 75
# At random state 432 model performs well
# At random state  432
# 76
# At random state 450 model performs well
# At random state  450
# 75
# At random state 457 model performs well
# At random state  457
# 76
# At random state 462 model performs well
# At random state  462
# 76
# At random state 467 model performs well
# At random state  467
# 75
# At random state 487 model performs well
# At random state  487
# 76
# At random state 495 model performs well
# At random state  495
# 75
# At random state 504 model performs well
# At random state  504
# 75
# At random state 514 model performs well
# At random state  514
# 75
# At random state 520 model performs well
# At random state  520
# 76
# At random state 524 model performs well
# At random state  524
# 75
# At random state 536 model performs well
# At random state  536
# 76
# At random state 539 model performs well
# At random state  539
# 75
# At random state 549 model performs well
# At random state  549
# 75
# At random state 556 model performs well
# At random state  556
# 75
# At random state 557 model performs well
# At random state  557
# 76
# At random state 560 model performs well
# At random state  560
# 75
# At random state 567 model performs well
# At random state  567
# 75
# At random state 570 model performs well
# At random state  570
# 75
# At random state 580 model performs well
# At random state  580
# 75
# At random state 583 model performs well
# At random state  583
# 76
# At random state 593 model performs well
# At random state  593
# 76
# At random state 607 model performs well
# At random state  607
# 76
# At random state 620 model performs well
# At random state  620
# 75
# At random state 630 model performs well
# At random state  630
# 76
# At random state 632 model performs well
# At random state  632
# 76
# At random state 640 model performs well
# At random state  640
# 75
# At random state 644 model performs well
# At random state  644
# 75
# At random state 646 model performs well
# At random state  646
# 75
# At random state 647 model performs well
# At random state  647
# 75
# At random state 649 model performs well
# At random state  649
# 76
# At random state 651 model performs well
# At random state  651
# 75
# At random state 665 model performs well
# At random state  665
# 75
# At random state 666 model performs well
# At random state  666
# 76
# At random state 668 model performs well
# At random state  668
# 75
# At random state 672 model performs well
# At random state  672
# 75
# At random state 681 model performs well
# At random state  681
# 75
# At random state 689 model performs well
# At random state  689
# 75
# At random state 701 model performs well
# At random state  701
# 75
# At random state 707 model performs well
# At random state  707
# 75
# At random state 713 model performs well
# At random state  713
# 75
# At random state 723 model performs well
# At random state  723
# 76
# At random state 725 model performs well
# At random state  725
# 76
# At random state 726 model performs well
# At random state  726
# 76
# At random state 729 model performs well
# At random state  729
# 75
# At random state 731 model performs well
# At random state  731
# 75
# At random state 737 model performs well
# At random state  737
# 75
# At random state 740 model performs well
# At random state  740
# 76
# At random state 741 model performs well
# At random state  741
# 75
# At random state 745 model performs well
# At random state  745
# 75
# At random state 751 model performs well
# At random state  751
# 76
# At random state 757 model performs well
# At random state  757
# 76
# At random state 769 model performs well
# At random state  769
# 75
# At random state 770 model performs well
# At random state  770
# 76
# At random state 787 model performs well
# At random state  787
# 75
# At random state 789 model performs well
# At random state  789
# 76
# At random state 792 model performs well
# At random state  792
# 75
# At random state 795 model performs well
# At random state  795
# 75
# At random state 804 model performs well
# At random state  804
# 75
# At random state 806 model performs well
# At random state  806
# 75
# At random state 810 model performs well
# At random state  810
# 76
# At random state 824 model performs well
# At random state  824
# 76
# At random state 825 model performs well
# At random state  825
# 76
# At random state 837 model performs well
# At random state  837
# 76
# At random state 840 model performs well
# At random state  840
# 76
# At random state 847 model performs well
# At random state  847
# 76
# At random state 853 model performs well
# At random state  853
# 75
# At random state 857 model performs well
# At random state  857
# 76
# At random state 859 model performs well
# At random state  859
# 76
# At random state 875 model performs well
# At random state  875
# 76
# At random state 878 model performs well
# At random state  878
# 75
# At random state 885 model performs well
# At random state  885
# 76
# At random state 904 model performs well
# At random state  904
# 76
# At random state 907 model performs well
# At random state  907
# 75
# At random state 913 model performs well
# At random state  913
# 76
# At random state 923 model performs well
# At random state  923
# 75
# At random state 928 model performs well
# At random state  928
# 75
# At random state 947 model performs well
# At random state  947
# 76
# At random state 953 model performs well
# At random state  953
# 76
# At random state 957 model performs well
# At random state  957
# 76
# At random state 959 model performs well
# At random state  959
# 76
# At random state 968 model performs well
# At random state  968
# 75

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,annot_kws={'size':10},fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       217
#            1       0.78      0.75      0.76       229
#
#     accuracy                           0.76       446
#    macro avg       0.76      0.76      0.76       446
# weighted avg       0.76      0.76      0.76       446

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(lr,pc,y,cv=5).mean()
# Out:
# 0.7486759486759487

# %%
x_train,x_test,y_train,y_test=train_test_split(pc,y,test_size=0.30,random_state=432)

# %%
def model(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        ypred=clf.predict(x_train)
        print(accuracy_score(y_train,ypred)*100)
    elif train==False:
        y_pred=clf.predict(x_test)
        print(accuracy_score(y_test,y_pred)*100)
        print(classification_report(y_test,y_pred))
        sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,annot_kws={'size':10},fmt='.2f')
        print('*'*100)
        print('cross_val_score',cross_val_score(clf,pc,y,cv=5).mean())

# %% [markdown]
# # KNN

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model(knn,x_train,x_test,y_train,y_test,train=True)
# Out:
# 78.22736030828517

# %%
model(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
# 67.04035874439462
#               precision    recall  f1-score   support
#
#            0       0.90      0.39      0.55       226
#            1       0.61      0.95      0.74       220
#
#     accuracy                           0.67       446
#    macro avg       0.75      0.67      0.64       446
# weighted avg       0.75      0.67      0.64       446
#
# ****************************************************************************************************
# cross_val_score 0.7055487305487306

# %% [markdown]
# # Decision Tree

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model(dt,x_train,x_test,y_train,y_test,train=True)
# Out:
# 100.0

# %%
model(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
# 74.66367713004485
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75       226
#            1       0.74      0.75      0.74       220
#
#     accuracy                           0.75       446
#    macro avg       0.75      0.75      0.75       446
# weighted avg       0.75      0.75      0.75       446
#
# ****************************************************************************************************
# cross_val_score 0.7641618891618892

# %% [markdown]
# # Random Forest

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)
# Out:
# 100.0

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
# 86.54708520179372
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       226
#            1       0.87      0.85      0.86       220
#
#     accuracy                           0.87       446
#    macro avg       0.87      0.87      0.87       446
# weighted avg       0.87      0.87      0.87       446
#
# ****************************************************************************************************
# cross_val_score 0.8834516334516334

# %% [markdown]
# # Bagging Classifier

# %%
bg=BaggingClassifier()
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
model(bg,x_train,x_test,y_train,y_test,train=True)
# Out:
# 99.22928709055877

# %%
model(bg,x_train,x_test,y_train,y_test,train=False)
# Out:
# 79.5964125560538
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       226
#            1       0.80      0.78      0.79       220
#
#     accuracy                           0.80       446
#    macro avg       0.80      0.80      0.80       446
# weighted avg       0.80      0.80      0.80       446
#
# ****************************************************************************************************
# cross_val_score 0.8228023478023478

# %% [markdown]
# # GradientBoosting Classifier

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
model(gb,x_train,x_test,y_train,y_test,train=True)
# Out:
# 97.59152215799615

# %%
model(gb,x_train,x_test,y_train,y_test,train=False)
# Out:
# 80.94170403587444
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.80       226
#            1       0.78      0.85      0.81       220
#
#     accuracy                           0.81       446
#    macro avg       0.81      0.81      0.81       446
# weighted avg       0.81      0.81      0.81       446
#
# ****************************************************************************************************
# cross_val_score 0.8383087633087634

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
model(svc,x_train,x_test,y_train,y_test,train=True)
# Out:
# 94.79768786127167

# %%
model(svc,x_train,x_test,y_train,y_test,train=False)
# Out:
# 84.97757847533633
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85       226
#            1       0.83      0.88      0.85       220
#
#     accuracy                           0.85       446
#    macro avg       0.85      0.85      0.85       446
# weighted avg       0.85      0.85      0.85       446
#
# ****************************************************************************************************
# cross_val_score 0.8618777868777869

# %% [markdown]
# # Conclusion:- Random Forest and SVM is best performing model which has almost same F1 score and cross validation score

# %%
# Hyperparameter Tunning
from sklearn.model_selection import GridSearchCV

# %%
# Random Forest
params={'n_estimators':[100],
       'criterion':['gini','entropy'],
       'max_depth':[4,5,6,7,8,9],
       'min_samples_split':[3,4,5,6,7],
       'min_samples_leaf':[3,4,5,7,9]}

# %%
gs=GridSearchCV(rf,param_grid=params,n_jobs=-1)
gs.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [3, 4, 5, 7, 9],
#                          'min_samples_split': [3, 4, 5, 6, 7],
#                          'n_estimators': [100]})

# %%
gs.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 9,
#  'min_samples_leaf': 4,
#  'min_samples_split': 7,
#  'n_estimators': 100}

# %%
rf=RandomForestClassifier(criterion='entropy',max_depth=10,min_samples_leaf=4,min_samples_split=8,n_estimators=100)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, min_samples_leaf=4,
#                        min_samples_split=8)

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)
# Out:
# 97.39884393063583

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
# 85.20179372197309
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       226
#            1       0.83      0.87      0.85       220
#
#     accuracy                           0.85       446
#    macro avg       0.85      0.85      0.85       446
# weighted avg       0.85      0.85      0.85       446
#
# ****************************************************************************************************
# cross_val_score 0.8504390754390754

# %%
y_pred=rf.predict(x_test)

# %%
Pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
Pred
# Out:
#       Actual  Predicted
# 1145       1          1
# 1020       1          1
# 1106       1          1
# 836        0          0
# 833        0          0
# ...      ...        ...
# 1009       1          1
# 744        0          1
# 754        0          0
# 162        0          0
# 490        0          0
#
# [446 rows x 2 columns]

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(y_test,y_pred,color='red')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted')

# %%
disp=plot_roc_curve(rf,pc,y)
plot_roc_curve(lr,pc,y,ax=disp.ax_)
plot_roc_curve(knn,pc,y,ax=disp.ax_)
plot_roc_curve(svc,pc,y,ax=disp.ax_)
plot_roc_curve(bg,pc,y,ax=disp.ax_)
plot_roc_curve(gb,pc,y,ax=disp.ax_)

# %% [markdown]
# # Final Conclusion:- Random Forest is best performing model with Accuracy_score=Cross_val_score=F1 Score=85%

# %%
# Saving the model
import pickle
filename='Insurance_Fraud'
pickle.dump(rf,open(filename,'wb'))
